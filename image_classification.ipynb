# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
import sys
print (sys.version)
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# 3.5.3 |Continuum Analytics, Inc.| (default, Mar  6 2017, 12:15:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 3:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return (x - x.min(0))/x.ptp(0)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    from sklearn.preprocessing import LabelBinarizer 
    lb = LabelBinarizer()
    encoding_map = range(0,10)
    lb.fit(encoding_map)
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=([None, image_shape[0], image_shape[1], image_shape[2]]), name="x")



def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None,n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function    
    x_tensor_shape = np.shape(x_tensor).as_list()
    #weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], np.shape(x_tensor)[3], conv_num_outputs], stddev=0.1)) #[patch_size[0], patch_size[1], input_channels, output_channels]
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor_shape[3], conv_num_outputs], stddev=0.1)) #[patch_size[0], patch_size[1], input_channels, output_channels]
    bias = tf.Variable(tf.constant(0.1, shape=[conv_num_outputs]))

    h_conv1 = tf.nn.conv2d(x_tensor, weight, strides=[1,conv_strides[0],conv_strides[1],1], padding='SAME')
    h_conv1 = tf.nn.bias_add(h_conv1, bias)
    h_conv1 = tf.nn.relu(h_conv1)
    
    return tf.nn.max_pool(h_conv1, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x_tensor_shape = x_tensor.get_shape().as_list()    
    return tf.reshape(x_tensor, (-1, x_tensor_shape[1]*x_tensor_shape[2]*x_tensor_shape[3]))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_tensor_shape = np.shape(x_tensor).as_list()
    weight = tf.Variable(tf.truncated_normal(shape=[x_tensor_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.constant(0.1, shape=[num_outputs]))
    return tf.nn.relu(tf.matmul(x_tensor, weight) + bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# [None, 128]
# 40
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_tensor_shape = np.shape(x_tensor).as_list()
    weight = tf.Variable(tf.truncated_normal(shape=[x_tensor_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.constant(0.1, shape=[num_outputs]))
    return tf.nn.relu(tf.matmul(x_tensor, weight) + bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #conv1 = 50, (2,2), (2,2), (3,3), (3,3) #(conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #conv2 = ()
    #conv3 = ()
    x = conv2d_maxpool(x, 30, (3,3), (3,2), (3,3), (3,2))
    x = conv2d_maxpool(x, 50, (3,3), (2,2), (3,3), (3,3))
    x = conv2d_maxpool(x, 70, (2,2), (2,2), (2,2), (2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    x = tf.nn.dropout(x, keep_prob)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 30)
    x = fully_conn(x, 50)
    x = fully_conn(x, 70)
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)

    # TODO: return output
    # return output(x, np.shape(y)[1])
    return output(x, y.get_shape().as_list()[1])
  
    print("this is test for np.shape(y)[1]:",np.shape(y)[1])
    print("this is test for y.get_shape().as_list()[1]:",y.get_shape().as_list()[1])
    print("both lines output as number 10, one works but the other doesn't. don't know why.")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [None, 70]
# 30
# [None, 30]
# 50
# [None, 50]
# 70
# [None, 70]
# 30
# [None, 30]
# 50
# [None, 50]
# 70
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print("accuracy = ", session.run(accuracy, feed_dict={x: feature_batch, y: label_batch, keep_prob:1.0}))
    print("cost = ", session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob:1.0}))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 86
batch_size = 64
keep_probability = 1

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  accuracy =  0.2
# cost =  2.25189
# Epoch  2, CIFAR-10 Batch 1:  accuracy =  0.125
# cost =  2.1008
# Epoch  3, CIFAR-10 Batch 1:  accuracy =  0.15
# cost =  2.06985
# Epoch  4, CIFAR-10 Batch 1:  accuracy =  0.15
# cost =  2.08048
# Epoch  5, CIFAR-10 Batch 1:  accuracy =  0.275
# cost =  1.90847
# Epoch  6, CIFAR-10 Batch 1:  accuracy =  0.375
# cost =  1.88212
# Epoch  7, CIFAR-10 Batch 1:  accuracy =  0.4
# cost =  1.77791
# Epoch  8, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.71291
# Epoch  9, CIFAR-10 Batch 1:  accuracy =  0.475
# cost =  1.70109
# Epoch 10, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.65438
# Epoch 11, CIFAR-10 Batch 1:  accuracy =  0.475
# cost =  1.66264
# Epoch 12, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.63062
# Epoch 13, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.60273
# Epoch 14, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.57329
# Epoch 15, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.51141
# Epoch 16, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.47236
# Epoch 17, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.44468
# Epoch 18, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.43092
# Epoch 19, CIFAR-10 Batch 1:  accuracy =  0.575
# cost =  1.39036
# Epoch 20, CIFAR-10 Batch 1:  accuracy =  0.575
# cost =  1.37681
# Epoch 21, CIFAR-10 Batch 1:  accuracy =  0.575
# cost =  1.35961
# Epoch 22, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.31506
# Epoch 23, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.29604
# Epoch 24, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.26018
# Epoch 25, CIFAR-10 Batch 1:  accuracy =  0.575
# cost =  1.24567
# Epoch 26, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.24276
# Epoch 27, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.23058
# Epoch 28, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.27056
# Epoch 29, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.23036
# Epoch 30, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.24801
# Epoch 31, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.2463
# Epoch 32, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.28693
# Epoch 33, CIFAR-10 Batch 1:  accuracy =  0.575
# cost =  1.30696
# Epoch 34, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.36367
# Epoch 35, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.17866
# Epoch 36, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.15931
# Epoch 37, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.17241
# Epoch 38, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.1673
# Epoch 39, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.15962
# Epoch 40, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.13868
# Epoch 41, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.14069
# Epoch 42, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.10653
# Epoch 43, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.07698
# Epoch 44, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.05295
# Epoch 45, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.03797
# Epoch 46, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.00315
# Epoch 47, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  1.01406
# Epoch 48, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  1.02513
# Epoch 49, CIFAR-10 Batch 1:  accuracy =  0.75
# cost =  0.994055
# Epoch 50, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  1.02484
# Epoch 51, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.08565
# Epoch 52, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.03831
# Epoch 53, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.0747
# Epoch 54, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.04755
# Epoch 55, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.978996
# Epoch 56, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.946633
# Epoch 57, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.983273
# Epoch 58, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.957988
# Epoch 59, CIFAR-10 Batch 1:  accuracy =  0.75
# cost =  0.925672
# Epoch 60, CIFAR-10 Batch 1:  accuracy =  0.75
# cost =  0.896144
# Epoch 61, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.934827
# Epoch 62, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.894536
# Epoch 63, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.881851
# Epoch 64, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.881766
# Epoch 65, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.865644
# Epoch 66, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.833132
# Epoch 67, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.861287
# Epoch 68, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.908363
# Epoch 69, CIFAR-10 Batch 1:  accuracy =  0.75
# cost =  0.913881
# Epoch 70, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.864834
# Epoch 71, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.806103
# Epoch 72, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.769668
# Epoch 73, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.770103
# Epoch 74, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.727448
# Epoch 75, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.719863
# Epoch 76, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.820677
# Epoch 77, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.767803
# Epoch 78, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.704719
# Epoch 79, CIFAR-10 Batch 1:  accuracy =  0.825
# cost =  0.639748
# Epoch 80, CIFAR-10 Batch 1:  accuracy =  0.775
# cost =  0.7777
# Epoch 81, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.751526
# Epoch 82, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.69643
# Epoch 83, CIFAR-10 Batch 1:  accuracy =  0.825
# cost =  0.585213
# Epoch 84, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.671849
# Epoch 85, CIFAR-10 Batch 1:  accuracy =  0.825
# cost =  0.636635
# Epoch 86, CIFAR-10 Batch 1:  accuracy =  0.8
# cost =  0.65701

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  accuracy =  0.25
# cost =  2.24858
# Epoch  1, CIFAR-10 Batch 2:  accuracy =  0.2
# cost =  2.13502
# Epoch  1, CIFAR-10 Batch 3:  accuracy =  0.325
# cost =  1.99365
# Epoch  1, CIFAR-10 Batch 4:  accuracy =  0.375
# cost =  1.84345
# Epoch  1, CIFAR-10 Batch 5:  accuracy =  0.275
# cost =  2.01192
# Epoch  2, CIFAR-10 Batch 1:  accuracy =  0.225
# cost =  2.13073
# Epoch  2, CIFAR-10 Batch 2:  accuracy =  0.45
# cost =  1.64992
# Epoch  2, CIFAR-10 Batch 3:  accuracy =  0.55
# cost =  1.41884
# Epoch  2, CIFAR-10 Batch 4:  accuracy =  0.5
# cost =  1.58466
# Epoch  2, CIFAR-10 Batch 5:  accuracy =  0.35
# cost =  1.79429
# Epoch  3, CIFAR-10 Batch 1:  accuracy =  0.45
# cost =  1.77799
# Epoch  3, CIFAR-10 Batch 2:  accuracy =  0.5
# cost =  1.53519
# Epoch  3, CIFAR-10 Batch 3:  accuracy =  0.55
# cost =  1.28993
# Epoch  3, CIFAR-10 Batch 4:  accuracy =  0.5
# cost =  1.53604
# Epoch  3, CIFAR-10 Batch 5:  accuracy =  0.375
# cost =  1.71765
# Epoch  4, CIFAR-10 Batch 1:  accuracy =  0.475
# cost =  1.74115
# Epoch  4, CIFAR-10 Batch 2:  accuracy =  0.55
# cost =  1.43098
# Epoch  4, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  1.23822
# Epoch  4, CIFAR-10 Batch 4:  accuracy =  0.5
# cost =  1.4699
# Epoch  4, CIFAR-10 Batch 5:  accuracy =  0.45
# cost =  1.61614
# Epoch  5, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.67629
# Epoch  5, CIFAR-10 Batch 2:  accuracy =  0.525
# cost =  1.36264
# Epoch  5, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.20441
# Epoch  5, CIFAR-10 Batch 4:  accuracy =  0.525
# cost =  1.438
# Epoch  5, CIFAR-10 Batch 5:  accuracy =  0.5
# cost =  1.5575
# Epoch  6, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.66852
# Epoch  6, CIFAR-10 Batch 2:  accuracy =  0.55
# cost =  1.34259
# Epoch  6, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.19384
# Epoch  6, CIFAR-10 Batch 4:  accuracy =  0.525
# cost =  1.38503
# Epoch  6, CIFAR-10 Batch 5:  accuracy =  0.525
# cost =  1.53157
# Epoch  7, CIFAR-10 Batch 1:  accuracy =  0.475
# cost =  1.65552
# Epoch  7, CIFAR-10 Batch 2:  accuracy =  0.525
# cost =  1.31377
# Epoch  7, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  1.15819
# Epoch  7, CIFAR-10 Batch 4:  accuracy =  0.525
# cost =  1.29472
# Epoch  7, CIFAR-10 Batch 5:  accuracy =  0.5
# cost =  1.51735
# Epoch  8, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.6264
# Epoch  8, CIFAR-10 Batch 2:  accuracy =  0.525
# cost =  1.28633
# Epoch  8, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.1449
# Epoch  8, CIFAR-10 Batch 4:  accuracy =  0.6
# cost =  1.2418
# Epoch  8, CIFAR-10 Batch 5:  accuracy =  0.525
# cost =  1.47936
# Epoch  9, CIFAR-10 Batch 1:  accuracy =  0.475
# cost =  1.62248
# Epoch  9, CIFAR-10 Batch 2:  accuracy =  0.5
# cost =  1.21551
# Epoch  9, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  1.10563
# Epoch  9, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.19868
# Epoch  9, CIFAR-10 Batch 5:  accuracy =  0.525
# cost =  1.43867
# Epoch 10, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.54869
# Epoch 10, CIFAR-10 Batch 2:  accuracy =  0.575
# cost =  1.16908
# Epoch 10, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.086
# Epoch 10, CIFAR-10 Batch 4:  accuracy =  0.625
# cost =  1.18979
# Epoch 10, CIFAR-10 Batch 5:  accuracy =  0.525
# cost =  1.45193
# Epoch 11, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.49523
# Epoch 11, CIFAR-10 Batch 2:  accuracy =  0.575
# cost =  1.12575
# Epoch 11, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  1.07116
# Epoch 11, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.17546
# Epoch 11, CIFAR-10 Batch 5:  accuracy =  0.55
# cost =  1.43628
# Epoch 12, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.49481
# Epoch 12, CIFAR-10 Batch 2:  accuracy =  0.575
# cost =  1.09531
# Epoch 12, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.0596
# Epoch 12, CIFAR-10 Batch 4:  accuracy =  0.625
# cost =  1.14596
# Epoch 12, CIFAR-10 Batch 5:  accuracy =  0.5
# cost =  1.39637
# Epoch 13, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.44157
# Epoch 13, CIFAR-10 Batch 2:  accuracy =  0.625
# cost =  1.06155
# Epoch 13, CIFAR-10 Batch 3:  accuracy =  0.6
# cost =  1.02712
# Epoch 13, CIFAR-10 Batch 4:  accuracy =  0.675
# cost =  1.1447
# Epoch 13, CIFAR-10 Batch 5:  accuracy =  0.6
# cost =  1.36302
# Epoch 14, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.42619
# Epoch 14, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.05477
# Epoch 14, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  1.01019
# Epoch 14, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.11402
# Epoch 14, CIFAR-10 Batch 5:  accuracy =  0.55
# cost =  1.32795
# Epoch 15, CIFAR-10 Batch 1:  accuracy =  0.5
# cost =  1.37026
# Epoch 15, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.04637
# Epoch 15, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.999523
# Epoch 15, CIFAR-10 Batch 4:  accuracy =  0.675
# cost =  1.13365
# Epoch 15, CIFAR-10 Batch 5:  accuracy =  0.625
# cost =  1.28412
# Epoch 16, CIFAR-10 Batch 1:  accuracy =  0.525
# cost =  1.3193
# Epoch 16, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.02525
# Epoch 16, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.989824
# Epoch 16, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.10011
# Epoch 16, CIFAR-10 Batch 5:  accuracy =  0.6
# cost =  1.24679
# Epoch 17, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.3358
# Epoch 17, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.04906
# Epoch 17, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.988755
# Epoch 17, CIFAR-10 Batch 4:  accuracy =  0.675
# cost =  1.06636
# Epoch 17, CIFAR-10 Batch 5:  accuracy =  0.6
# cost =  1.20784
# Epoch 18, CIFAR-10 Batch 1:  accuracy =  0.55
# cost =  1.28161
# Epoch 18, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.05468
# Epoch 18, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.967506
# Epoch 18, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.0414
# Epoch 18, CIFAR-10 Batch 5:  accuracy =  0.625
# cost =  1.21491
# Epoch 19, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.22759
# Epoch 19, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  1.07119
# Epoch 19, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.95857
# Epoch 19, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  1.01911
# Epoch 19, CIFAR-10 Batch 5:  accuracy =  0.575
# cost =  1.19378
# Epoch 20, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.22648
# Epoch 20, CIFAR-10 Batch 2:  accuracy =  0.625
# cost =  1.06111
# Epoch 20, CIFAR-10 Batch 3:  accuracy =  0.675
# cost =  0.948456
# Epoch 20, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.997282
# Epoch 20, CIFAR-10 Batch 5:  accuracy =  0.6
# cost =  1.14821
# Epoch 21, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.1985
# Epoch 21, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  1.06559
# Epoch 21, CIFAR-10 Batch 3:  accuracy =  0.675
# cost =  0.946804
# Epoch 21, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.968308
# Epoch 21, CIFAR-10 Batch 5:  accuracy =  0.6
# cost =  1.10565
# Epoch 22, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.17811
# Epoch 22, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  1.07469
# Epoch 22, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.939099
# Epoch 22, CIFAR-10 Batch 4:  accuracy =  0.625
# cost =  0.962087
# Epoch 22, CIFAR-10 Batch 5:  accuracy =  0.625
# cost =  1.10412
# Epoch 23, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.16467
# Epoch 23, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  1.10618
# Epoch 23, CIFAR-10 Batch 3:  accuracy =  0.625
# cost =  0.89789
# Epoch 23, CIFAR-10 Batch 4:  accuracy =  0.625
# cost =  0.938898
# Epoch 23, CIFAR-10 Batch 5:  accuracy =  0.675
# cost =  1.10444
# Epoch 24, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.16838
# Epoch 24, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.08141
# Epoch 24, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.886164
# Epoch 24, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.871139
# Epoch 24, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  1.08968
# Epoch 25, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.12697
# Epoch 25, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  1.09452
# Epoch 25, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.835084
# Epoch 25, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.893139
# Epoch 25, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  1.03827
# Epoch 26, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.12862
# Epoch 26, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  0.995918
# Epoch 26, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.82007
# Epoch 26, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.859124
# Epoch 26, CIFAR-10 Batch 5:  accuracy =  0.675
# cost =  1.0231
# Epoch 27, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.1028
# Epoch 27, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  0.999267
# Epoch 27, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.766264
# Epoch 27, CIFAR-10 Batch 4:  accuracy =  0.65
# cost =  0.829007
# Epoch 27, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  0.989704
# Epoch 28, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.09368
# Epoch 28, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.932603
# Epoch 28, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.789619
# Epoch 28, CIFAR-10 Batch 4:  accuracy =  0.7
# cost =  0.813753
# Epoch 28, CIFAR-10 Batch 5:  accuracy =  0.65
# cost =  0.974913
# Epoch 29, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.05575
# Epoch 29, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  0.923748
# Epoch 29, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.778791
# Epoch 29, CIFAR-10 Batch 4:  accuracy =  0.7
# cost =  0.795581
# Epoch 29, CIFAR-10 Batch 5:  accuracy =  0.65
# cost =  0.958234
# Epoch 30, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.03915
# Epoch 30, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.929012
# Epoch 30, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.785969
# Epoch 30, CIFAR-10 Batch 4:  accuracy =  0.675
# cost =  0.806009
# Epoch 30, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  0.917475
# Epoch 31, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.03689
# Epoch 31, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.890246
# Epoch 31, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.741152
# Epoch 31, CIFAR-10 Batch 4:  accuracy =  0.7
# cost =  0.789788
# Epoch 31, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.917989
# Epoch 32, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  1.00546
# Epoch 32, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.886039
# Epoch 32, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.73435
# Epoch 32, CIFAR-10 Batch 4:  accuracy =  0.675
# cost =  0.791153
# Epoch 32, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.855638
# Epoch 33, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.00177
# Epoch 33, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.900246
# Epoch 33, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.696332
# Epoch 33, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.799396
# Epoch 33, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.841344
# Epoch 34, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.0054
# Epoch 34, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  0.856099
# Epoch 34, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.702922
# Epoch 34, CIFAR-10 Batch 4:  accuracy =  0.75
# cost =  0.781943
# Epoch 34, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.843209
# Epoch 35, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  1.01484
# Epoch 35, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.873475
# Epoch 35, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.712121
# Epoch 35, CIFAR-10 Batch 4:  accuracy =  0.75
# cost =  0.740277
# Epoch 35, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.841774
# Epoch 36, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.985611
# Epoch 36, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.861186
# Epoch 36, CIFAR-10 Batch 3:  accuracy =  0.85
# cost =  0.725373
# Epoch 36, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.765933
# Epoch 36, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.815965
# Epoch 37, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.00425
# Epoch 37, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.809721
# Epoch 37, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.724894
# Epoch 37, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.724546
# Epoch 37, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.833549
# Epoch 38, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.997289
# Epoch 38, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.840011
# Epoch 38, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.687604
# Epoch 38, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.703219
# Epoch 38, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.812398
# Epoch 39, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.01978
# Epoch 39, CIFAR-10 Batch 2:  accuracy =  0.65
# cost =  0.830623
# Epoch 39, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.693505
# Epoch 39, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.696012
# Epoch 39, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.863188
# Epoch 40, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.03047
# Epoch 40, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  0.822027
# Epoch 40, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.696797
# Epoch 40, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.684649
# Epoch 40, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.800154
# Epoch 41, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.974154
# Epoch 41, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  0.804783
# Epoch 41, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.707842
# Epoch 41, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.664148
# Epoch 41, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  0.805069
# Epoch 42, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.960893
# Epoch 42, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.791113
# Epoch 42, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.668393
# Epoch 42, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.641237
# Epoch 42, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.822339
# Epoch 43, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.00441
# Epoch 43, CIFAR-10 Batch 2:  accuracy =  0.675
# cost =  0.78907
# Epoch 43, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.697461
# Epoch 43, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.65029
# Epoch 43, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.800848
# Epoch 44, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.0043
# Epoch 44, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.800934
# Epoch 44, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.669678
# Epoch 44, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.625139
# Epoch 44, CIFAR-10 Batch 5:  accuracy =  0.825
# cost =  0.788005
# Epoch 45, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.983779
# Epoch 45, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.79278
# Epoch 45, CIFAR-10 Batch 3:  accuracy =  0.675
# cost =  0.71036
# Epoch 45, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.666185
# Epoch 45, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.795798
# Epoch 46, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.01154
# Epoch 46, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.774032
# Epoch 46, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.702755
# Epoch 46, CIFAR-10 Batch 4:  accuracy =  0.75
# cost =  0.684361
# Epoch 46, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.776926
# Epoch 47, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.990218
# Epoch 47, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.744733
# Epoch 47, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.663973
# Epoch 47, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.708788
# Epoch 47, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.746056
# Epoch 48, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  1.03166
# Epoch 48, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.747336
# Epoch 48, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.719946
# Epoch 48, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.658077
# Epoch 48, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.736365
# Epoch 49, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.977316
# Epoch 49, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.75751
# Epoch 49, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.67181
# Epoch 49, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.649076
# Epoch 49, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.748732
# Epoch 50, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.963915
# Epoch 50, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.745848
# Epoch 50, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.701757
# Epoch 50, CIFAR-10 Batch 4:  accuracy =  0.85
# cost =  0.617633
# Epoch 50, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.756876
# Epoch 51, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.959056
# Epoch 51, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.721991
# Epoch 51, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.686812
# Epoch 51, CIFAR-10 Batch 4:  accuracy =  0.85
# cost =  0.608855
# Epoch 51, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.740435
# Epoch 52, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  1.00569
# Epoch 52, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.701686
# Epoch 52, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.716029
# Epoch 52, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.614165
# Epoch 52, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.739589
# Epoch 53, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.948253
# Epoch 53, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.741078
# Epoch 53, CIFAR-10 Batch 3:  accuracy =  0.7
# cost =  0.678507
# Epoch 53, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.580498
# Epoch 53, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.740967
# Epoch 54, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.960547
# Epoch 54, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.800236
# Epoch 54, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.661344
# Epoch 54, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.591756
# Epoch 54, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.721701
# Epoch 55, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.98994
# Epoch 55, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.880696
# Epoch 55, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.682144
# Epoch 55, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.539403
# Epoch 55, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.750548
# Epoch 56, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.953246
# Epoch 56, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.752365
# Epoch 56, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.673197
# Epoch 56, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.569481
# Epoch 56, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.758799
# Epoch 57, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.93061
# Epoch 57, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.816197
# Epoch 57, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.723183
# Epoch 57, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.554275
# Epoch 57, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.739124
# Epoch 58, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.900509
# Epoch 58, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.763418
# Epoch 58, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.677837
# Epoch 58, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.508758
# Epoch 58, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.749776
# Epoch 59, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.939364
# Epoch 59, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.734778
# Epoch 59, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.70117
# Epoch 59, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.5387
# Epoch 59, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.780013
# Epoch 60, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.985372
# Epoch 60, CIFAR-10 Batch 2:  accuracy =  0.7
# cost =  0.720069
# Epoch 60, CIFAR-10 Batch 3:  accuracy =  0.65
# cost =  0.737795
# Epoch 60, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.531836
# Epoch 60, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.714196
# Epoch 61, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.984148
# Epoch 61, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.670931
# Epoch 61, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.65999
# Epoch 61, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.52036
# Epoch 61, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.714694
# Epoch 62, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.962247
# Epoch 62, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.712848
# Epoch 62, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.631293
# Epoch 62, CIFAR-10 Batch 4:  accuracy =  0.75
# cost =  0.577526
# Epoch 62, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.756576
# Epoch 63, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.981088
# Epoch 63, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.748286
# Epoch 63, CIFAR-10 Batch 3:  accuracy =  0.675
# cost =  0.73883
# Epoch 63, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.575574
# Epoch 63, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.794894
# Epoch 64, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.950834
# Epoch 64, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.705639
# Epoch 64, CIFAR-10 Batch 3:  accuracy =  0.675
# cost =  0.724137
# Epoch 64, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.554402
# Epoch 64, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.818973
# Epoch 65, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.973113
# Epoch 65, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.655677
# Epoch 65, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.70035
# Epoch 65, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.568089
# Epoch 65, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.806742
# Epoch 66, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.950936
# Epoch 66, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.671719
# Epoch 66, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.664601
# Epoch 66, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.579751
# Epoch 66, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.76838
# Epoch 67, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  1.01369
# Epoch 67, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.685179
# Epoch 67, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.62539
# Epoch 67, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.571829
# Epoch 67, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.755599
# Epoch 68, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.936235
# Epoch 68, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.632578
# Epoch 68, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.643307
# Epoch 68, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.513132
# Epoch 68, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.736317
# Epoch 69, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.923037
# Epoch 69, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.647377
# Epoch 69, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.674992
# Epoch 69, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.557797
# Epoch 69, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.731283
# Epoch 70, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.910584
# Epoch 70, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.651981
# Epoch 70, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.635657
# Epoch 70, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.548226
# Epoch 70, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.754198
# Epoch 71, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.895417
# Epoch 71, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.589954
# Epoch 71, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.656119
# Epoch 71, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.529603
# Epoch 71, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.761149
# Epoch 72, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.908736
# Epoch 72, CIFAR-10 Batch 2:  accuracy =  0.725
# cost =  0.650006
# Epoch 72, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.680447
# Epoch 72, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.546491
# Epoch 72, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.743048
# Epoch 73, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.887752
# Epoch 73, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.635595
# Epoch 73, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.61345
# Epoch 73, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.553815
# Epoch 73, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.737884
# Epoch 74, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.8732
# Epoch 74, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.583937
# Epoch 74, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.664739
# Epoch 74, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.568327
# Epoch 74, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.756089
# Epoch 75, CIFAR-10 Batch 1:  accuracy =  0.7
# cost =  0.920774
# Epoch 75, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.574737
# Epoch 75, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.623436
# Epoch 75, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.510634
# Epoch 75, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.751636
# Epoch 76, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.940345
# Epoch 76, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.518795
# Epoch 76, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.624793
# Epoch 76, CIFAR-10 Batch 4:  accuracy =  0.85
# cost =  0.524479
# Epoch 76, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.753434
# Epoch 77, CIFAR-10 Batch 1:  accuracy =  0.725
# cost =  0.925895
# Epoch 77, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.573908
# Epoch 77, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.626555
# Epoch 77, CIFAR-10 Batch 4:  accuracy =  0.725
# cost =  0.565608
# Epoch 77, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.709636
# Epoch 78, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.911191
# Epoch 78, CIFAR-10 Batch 2:  accuracy =  0.825
# cost =  0.533547
# Epoch 78, CIFAR-10 Batch 3:  accuracy =  0.775
# cost =  0.650857
# Epoch 78, CIFAR-10 Batch 4:  accuracy =  0.775
# cost =  0.522029
# Epoch 78, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.69684
# Epoch 79, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.937023
# Epoch 79, CIFAR-10 Batch 2:  accuracy =  0.775
# cost =  0.561792
# Epoch 79, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.674714
# Epoch 79, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.482574
# Epoch 79, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.71222
# Epoch 80, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.886226
# Epoch 80, CIFAR-10 Batch 2:  accuracy =  0.75
# cost =  0.608546
# Epoch 80, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.64263
# Epoch 80, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.50848
# Epoch 80, CIFAR-10 Batch 5:  accuracy =  0.7
# cost =  0.773648
# Epoch 81, CIFAR-10 Batch 1:  accuracy =  0.6
# cost =  0.959443
# Epoch 81, CIFAR-10 Batch 2:  accuracy =  0.825
# cost =  0.58215
# Epoch 81, CIFAR-10 Batch 3:  accuracy =  0.8
# cost =  0.629325
# Epoch 81, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.597519
# Epoch 81, CIFAR-10 Batch 5:  accuracy =  0.725
# cost =  0.779389
# Epoch 82, CIFAR-10 Batch 1:  accuracy =  0.625
# cost =  0.871477
# Epoch 82, CIFAR-10 Batch 2:  accuracy =  0.825
# cost =  0.582072
# Epoch 82, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.605128
# Epoch 82, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.577328
# Epoch 82, CIFAR-10 Batch 5:  accuracy =  0.775
# cost =  0.714439
# Epoch 83, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.893339
# Epoch 83, CIFAR-10 Batch 2:  accuracy =  0.825
# cost =  0.52594
# Epoch 83, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.643878
# Epoch 83, CIFAR-10 Batch 4:  accuracy =  0.825
# cost =  0.475067
# Epoch 83, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.681091
# Epoch 84, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.860679
# Epoch 84, CIFAR-10 Batch 2:  accuracy =  0.85
# cost =  0.546263
# Epoch 84, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.623138
# Epoch 84, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.488985
# Epoch 84, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.679761
# Epoch 85, CIFAR-10 Batch 1:  accuracy =  0.675
# cost =  0.827669
# Epoch 85, CIFAR-10 Batch 2:  accuracy =  0.8
# cost =  0.509588
# Epoch 85, CIFAR-10 Batch 3:  accuracy =  0.75
# cost =  0.594891
# Epoch 85, CIFAR-10 Batch 4:  accuracy =  0.8
# cost =  0.573886
# Epoch 85, CIFAR-10 Batch 5:  accuracy =  0.8
# cost =  0.682401
# Epoch 86, CIFAR-10 Batch 1:  accuracy =  0.65
# cost =  0.840728
# Epoch 86, CIFAR-10 Batch 2:  accuracy =  0.8
# cost =  0.53195
# Epoch 86, CIFAR-10 Batch 3:  accuracy =  0.725
# cost =  0.627914
# Epoch 86, CIFAR-10 Batch 4:  accuracy =  0.85
# cost =  0.463264
# Epoch 86, CIFAR-10 Batch 5:  accuracy =  0.75
# cost =  0.688509

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5368232484076433

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
